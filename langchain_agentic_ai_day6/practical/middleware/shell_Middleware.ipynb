# %% [markdown]
# ## shell tool middle ware works on the bash hence run it on colab/mac as it has bash by defualt

# %%
# !pip install -U "langchain>=1.3.14"
# Out:
# Collecting langchain>=1.3.14
#   Downloading langchain-1.3.15-py3-none-any.whl.metadata (6.1 kB)
# Collecting langchain-core<2.0.0,>=1.5.4 (from langchain>=1.3.14)
#   Downloading langchain_core-1.5.5-py3-none-any.whl.metadata (4.8 kB)
# Collecting langgraph<1.3.0,>=1.2.11 (from langchain>=1.3.14)
#   Downloading langgraph-1.2.11-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.12/dist-packages (from langchain>=1.3.14) (2.13.4)
# Requirement already satisfied: httpx<1.0.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.5.4->langchain>=1.3.14) (0.28.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.5.4->langchain>=1.3.14) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.5.4->langchain>=1.3.14) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.5.4->langchain>=1.3.14) (0.10.2)
# Requirement already satisfied: packaging>=23.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.5.4->langchain>=1.3.14) (26.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.5.4->langchain>=1.3.14) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.5.4->langchain>=1.3.14) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.5.4->langchain>=1.3.14) (4.16.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.5.4->langchain>=1.3.14) (0.17.0)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.3.0,>=1.2.11->langchain>=1.3.14) (4.1.1)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.3.0,>=1.2.11->langchain>=1.3.14) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.5.0,>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.3.0,>=1.2.11->langchain>=1.3.14) (0.4.2)
# Requirement already satisfied: xxhash>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.3.0,>=1.2.11->langchain>=1.3.14) (3.8.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain>=1.3.14) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain>=1.3.14) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain>=1.3.14) (0.4.2)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.5.4->langchain>=1.3.14) (4.14.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.5.4->langchain>=1.3.14) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.5.4->langchain>=1.3.14) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.5.4->langchain>=1.3.14) (3.18)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.5.4->langchain>=1.3.14) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.5.4->langchain>=1.3.14) (3.1.1)
# Requirement already satisfied: ormsgpack>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph<1.3.0,>=1.2.11->langchain>=1.3.14) (1.12.2)
# Requirement already satisfied: orjson>=3.11.5 in /usr/local/lib/python3.12/dist-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.11->langchain>=1.3.14) (3.11.9)
# Requirement already satisfied: websockets<16,>=14 in /usr/local/lib/python3.12/dist-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.11->langchain>=1.3.14) (15.0.1)
# Requirement already satisfied: distro>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.5.4->langchain>=1.3.14) (1.9.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.5.4->langchain>=1.3.14) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.5.4->langchain>=1.3.14) (2.32.4)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.5.4->langchain>=1.3.14) (1.3.1)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.5.4->langchain>=1.3.14) (0.25.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.5.4->langchain>=1.3.14) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.5.4->langchain>=1.3.14) (2.5.0)
# Downloading langchain-1.3.15-py3-none-any.whl (147 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.0/147.0 kB 4.3 MB/s eta 0:00:00
# Downloading langchain_core-1.5.5-py3-none-any.whl (565 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 565.9/565.9 kB 17.4 MB/s eta 0:00:00
# Downloading langgraph-1.2.11-py3-none-any.whl (248 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 248.9/248.9 kB 15.8 MB/s eta 0:00:00
# Installing collected packages: langchain-core, langgraph, langchain
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 1.4.9
#     Uninstalling langchain-core-1.4.9:
#       Successfully uninstalled langchain-core-1.4.9
#   Attempting uninstall: langgraph
#     Found existing installation: langgraph 1.2.9
#     Uninstalling langgraph-1.2.9:
#       Successfully uninstalled langgraph-1.2.9
#   Attempting uninstall: langchain
#     Found existing installation: langchain 1.3.13
#     Uninstalling langchain-1.3.13:
#       Successfully uninstalled langchain-1.3.13
# Successfully installed langchain-1.3.15 langchain-core-1.5.5 langgraph-1.2.11

# %%
# !pip install  langchain-openai langchain-community langgraph python-dotenv langchain-mcp-adapters langchain-chroma chromadb pypdf
# Out:
# Collecting langchain-openai
#   Downloading langchain_openai-1.5.1-py3-none-any.whl.metadata (3.4 kB)
# Collecting langchain-community
#   Downloading langchain_community-0.4.2-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: langgraph in /usr/local/lib/python3.12/dist-packages (1.2.11)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.12/dist-packages (1.2.2)
# Collecting langchain-mcp-adapters
#   Downloading langchain_mcp_adapters-0.3.2-py3-none-any.whl.metadata (11 kB)
# Collecting langchain-chroma
#   Downloading langchain_chroma-1.1.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting chromadb
#   Downloading chromadb-1.5.9-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.0 kB)
# Collecting pypdf
#   Downloading pypdf-6.16.1-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: certifi>=2024.6.2 in /usr/local/lib/python3.12/dist-packages (from langchain-openai) (2026.6.17)
# Requirement already satisfied: langchain-core<2.0.0,>=1.5.4 in /usr/local/lib/python3.12/dist-packages (from langchain-openai) (1.5.5)
# Requirement already satisfied: openai<4.0.0,>=2.45.0 in /usr/local/lib/python3.12/dist-packages (from langchain-openai) (2.45.0)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from langchain-openai) (0.13.0)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (3.14.1)
# Collecting httpx-sse<1.0.0,>=0.4.0 (from langchain-community)
#   Downloading httpx_sse-0.4.3-py3-none-any.whl.metadata (9.7 kB)
# Collecting langchain-classic<2.0.0,>=1.0.7 (from langchain-community)
#   Downloading langchain_classic-1.0.8-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (0.10.2)
# Requirement already satisfied: numpy>=1.26.2 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (2.0.2)
# Collecting pydantic-settings<3.0.0,>=2.10.1 (from langchain-community)
#   Downloading pydantic_settings-2.15.0-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (6.0.3)
# Collecting requests<3.0.0,>=2.32.5 (from langchain-community)
#   Downloading requests-2.34.2-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (2.0.51)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (9.1.4)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from langgraph) (4.1.1)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from langgraph) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.5.0,>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from langgraph) (0.4.2)
# Requirement already satisfied: pydantic>=2.7.4 in /usr/local/lib/python3.12/dist-packages (from langgraph) (2.13.4)
# Requirement already satisfied: xxhash>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from langgraph) (3.8.1)
# Collecting mcp<2.0.0,>=1.24.0 (from langchain-mcp-adapters)
#   Downloading mcp-1.29.0-py3-none-any.whl.metadata (9.3 kB)
# Requirement already satisfied: typing-extensions>=4.14.0 in /usr/local/lib/python3.12/dist-packages (from langchain-mcp-adapters) (4.16.0)
# Collecting build>=1.0.3 (from chromadb)
#   Downloading build-1.5.0-py3-none-any.whl.metadata (5.7 kB)
# Collecting pybase64>=1.4.1 (from chromadb)
#   Downloading pybase64-1.5.0-cp312-cp312-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: uvicorn>=0.18.3 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.51.0)
# Collecting onnxruntime>=1.14.1 (from chromadb)
#   Downloading onnxruntime-1.28.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.5 kB)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from chromadb) (1.42.1)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb)
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.44.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from chromadb) (1.42.1)
# Requirement already satisfied: tokenizers>=0.13.2 in /usr/local/lib/python3.12/dist-packages (from chromadb) (0.22.2)
# Collecting pypika>=0.48.9 (from chromadb)
#   Downloading pypika-0.51.1-py2.py3-none-any.whl.metadata (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.0/52.0 kB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.65.0 in /usr/local/lib/python3.12/dist-packages (from chromadb) (4.67.3)
# Collecting overrides>=7.3.1 (from chromadb)
#   Downloading overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.12/dist-packages (from chromadb) (7.1.0)
# Requirement already satisfied: grpcio>=1.58.0 in /usr/local/lib/python3.12/dist-packages (from chromadb) (1.82.1)
# Collecting bcrypt>=4.0.1 (from chromadb)
#   Downloading bcrypt-5.0.0-cp39-abi3-manylinux_2_34_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: typer>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from chromadb) (0.26.8)
# Collecting kubernetes>=28.1.0 (from chromadb)
#   Downloading kubernetes-36.0.3-py2.py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: mmh3>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from chromadb) (5.2.1)
# Requirement already satisfied: orjson>=3.9.12 in /usr/local/lib/python3.12/dist-packages (from chromadb) (3.11.9)
# Requirement already satisfied: httpx>=0.27.0 in /usr/local/lib/python3.12/dist-packages (from chromadb) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.12/dist-packages (from chromadb) (13.9.4)
# Requirement already satisfied: jsonschema>=4.19.0 in /usr/local/lib/python3.12/dist-packages (from chromadb) (4.26.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.24.2)
# Requirement already satisfied: packaging>=24.0 in /usr/local/lib/python3.12/dist-packages (from build>=1.0.3->chromadb) (26.2)
# Collecting pyproject_hooks (from build>=1.0.3->chromadb)
#   Downloading pyproject_hooks-1.2.0-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx>=0.27.0->chromadb) (4.14.2)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx>=0.27.0->chromadb) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx>=0.27.0->chromadb) (3.18)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.16.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.19.0->chromadb) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.19.0->chromadb) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.19.0->chromadb) (2026.6.3)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from kubernetes>=28.1.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.12/dist-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /usr/local/lib/python3.12/dist-packages (from kubernetes>=28.1.0->chromadb) (1.9.0)
# Requirement already satisfied: requests-oauthlib in /usr/local/lib/python3.12/dist-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: urllib3!=2.6.0,>=1.24.2 in /usr/local/lib/python3.12/dist-packages (from kubernetes>=28.1.0->chromadb) (2.5.0)
# Collecting durationpy>=0.7 (from kubernetes>=28.1.0->chromadb)
#   Downloading durationpy-0.10-py3-none-any.whl.metadata (340 bytes)
# Collecting langchain-text-splitters<2.0.0,>=1.1.2 (from langchain-classic<2.0.0,>=1.0.7->langchain-community)
#   Downloading langchain_text_splitters-1.1.2-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.5.4->langchain-openai) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.5.4->langchain-openai) (0.0.18)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.5.4->langchain-openai) (0.17.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph) (1.12.2)
# Requirement already satisfied: websockets<16,>=14 in /usr/local/lib/python3.12/dist-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph) (15.0.1)
# Requirement already satisfied: distro>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.9.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.3.1)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.25.0)
# Requirement already satisfied: pyjwt>=2.10.1 in /usr/local/lib/python3.12/dist-packages (from pyjwt[crypto]>=2.10.1->mcp<2.0.0,>=1.24.0->langchain-mcp-adapters) (2.13.0)
# Requirement already satisfied: python-multipart>=0.0.9 in /usr/local/lib/python3.12/dist-packages (from mcp<2.0.0,>=1.24.0->langchain-mcp-adapters) (0.0.32)
# Collecting sse-starlette>=1.6.1 (from mcp<2.0.0,>=1.24.0->langchain-mcp-adapters)
#   Downloading sse_starlette-3.4.8-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: starlette>=0.27 in /usr/local/lib/python3.12/dist-packages (from mcp<2.0.0,>=1.24.0->langchain-mcp-adapters) (1.3.1)
# Requirement already satisfied: typing-inspection>=0.4.1 in /usr/local/lib/python3.12/dist-packages (from mcp<2.0.0,>=1.24.0->langchain-mcp-adapters) (0.4.2)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.12/dist-packages (from onnxruntime>=1.14.1->chromadb) (25.12.19)
# Requirement already satisfied: protobuf>=4.25.8 in /usr/local/lib/python3.12/dist-packages (from onnxruntime>=1.14.1->chromadb) (5.29.6)
# Requirement already satisfied: jiter<1,>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from openai<4.0.0,>=2.45.0->langchain-openai) (0.16.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.75.0)
# Collecting opentelemetry-exporter-otlp-proto-common==1.44.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading opentelemetry_exporter_otlp_proto_common-1.44.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting opentelemetry-proto==1.44.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading opentelemetry_proto-1.44.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-sdk>=1.2.0 (from chromadb)
#   Downloading opentelemetry_sdk-1.44.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting opentelemetry-api>=1.2.0 (from chromadb)
#   Downloading opentelemetry_api-1.44.0-py3-none-any.whl.metadata (1.4 kB)
# Collecting opentelemetry-semantic-conventions==0.65b0 (from opentelemetry-sdk>=1.2.0->chromadb)
#   Downloading opentelemetry_semantic_conventions-0.65b0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.7.4->langgraph) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.7.4->langgraph) (2.46.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.4.9)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->chromadb) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->chromadb) (2.20.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy<3.0.0,>=1.4.0->langchain-community) (3.5.3)
# Requirement already satisfied: regex in /usr/local/lib/python3.12/dist-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2025.11.3)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in /usr/local/lib/python3.12/dist-packages (from tokenizers>=0.13.2->chromadb) (1.23.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer>=0.9.0->chromadb) (0.0.4)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.12/dist-packages (from uvicorn>=0.18.3->uvicorn[standard]>=0.18.3->chromadb) (8.4.2)
# Requirement already satisfied: httptools>=0.8.0 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.8.0)
# Requirement already satisfied: uvloop>=0.15.1 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.22.1)
# Requirement already satisfied: watchfiles>=0.20 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.2.0)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.29.7)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (1.5.1)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.5.4->langchain-openai) (3.1.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: cryptography>=3.4.0 in /usr/local/lib/python3.12/dist-packages (from pyjwt[crypto]>=2.10.1->mcp<2.0.0,>=1.24.0->langchain-mcp-adapters) (49.0.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb) (3.3.1)
# Requirement already satisfied: cffi>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp<2.0.0,>=1.24.0->langchain-mcp-adapters) (2.1.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=2.0.0->cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp<2.0.0,>=1.24.0->langchain-mcp-adapters) (3.0)
# Downloading langchain_openai-1.5.1-py3-none-any.whl (123 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.7/123.7 kB 6.5 MB/s eta 0:00:00
# Downloading langchain_community-0.4.2-py3-none-any.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 39.0 MB/s eta 0:00:00
# Downloading langchain_mcp_adapters-0.3.2-py3-none-any.whl (28 kB)
# Downloading langchain_chroma-1.1.0-py3-none-any.whl (12 kB)
# Downloading chromadb-1.5.9-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (23.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.3/23.3 MB 70.7 MB/s eta 0:00:00
# Downloading pypdf-6.16.1-py3-none-any.whl (382 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 382.9/382.9 kB 25.3 MB/s eta 0:00:00
# Downloading bcrypt-5.0.0-cp39-abi3-manylinux_2_34_x86_64.whl (278 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 19.5 MB/s eta 0:00:00
# Downloading build-1.5.0-py3-none-any.whl (26 kB)
# Downloading httpx_sse-0.4.3-py3-none-any.whl (9.0 kB)
# Downloading kubernetes-36.0.3-py2.py3-none-any.whl (4.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 101.2 MB/s eta 0:00:00
# Downloading langchain_classic-1.0.8-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 53.5 MB/s eta 0:00:00
# Downloading mcp-1.29.0-py3-none-any.whl (223 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 223.4/223.4 kB 16.1 MB/s eta 0:00:00
# Downloading onnxruntime-1.28.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (19.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.2/19.2 MB 75.2 MB/s eta 0:00:00
# Downloading opentelemetry_exporter_otlp_proto_grpc-1.44.0-py3-none-any.whl (19 kB)
# Downloading opentelemetry_exporter_otlp_proto_common-1.44.0-py3-none-any.whl (17 kB)
# Downloading opentelemetry_proto-1.44.0-py3-none-any.whl (72 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.5/72.5 kB 4.6 MB/s eta 0:00:00
# Downloading opentelemetry_sdk-1.44.0-py3-none-any.whl (137 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.2/137.2 kB 9.0 MB/s eta 0:00:00
# Downloading opentelemetry_api-1.44.0-py3-none-any.whl (60 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 3.8 MB/s eta 0:00:00
# Downloading opentelemetry_semantic_conventions-0.65b0-py3-none-any.whl (204 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 204.6/204.6 kB 13.0 MB/s eta 0:00:00
# Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Downloading pybase64-1.5.0-cp312-cp312-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl (94 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.7/94.7 kB 6.7 MB/s eta 0:00:00
# Downloading pydantic_settings-2.15.0-py3-none-any.whl (69 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.4/69.4 kB 4.8 MB/s eta 0:00:00
# Downloading pypika-0.51.1-py2.py3-none-any.whl (60 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 4.4 MB/s eta 0:00:00
# Downloading requests-2.34.2-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 4.8 MB/s eta 0:00:00
# Downloading durationpy-0.10-py3-none-any.whl (3.9 kB)
# Downloading langchain_text_splitters-1.1.2-py3-none-any.whl (35 kB)
# Downloading sse_starlette-3.4.8-py3-none-any.whl (16 kB)
# Downloading pyproject_hooks-1.2.0-py3-none-any.whl (10 kB)
# Installing collected packages: pypika, durationpy, requests, pyproject_hooks, pypdf, pybase64, overrides, opentelemetry-proto, opentelemetry-api, onnxruntime, httpx-sse, bcrypt, opentelemetry-semantic-conventions, opentelemetry-exporter-otlp-proto-common, build, sse-starlette, pydantic-settings, opentelemetry-sdk, kubernetes, opentelemetry-exporter-otlp-proto-grpc, mcp, langchain-text-splitters, langchain-openai, langchain-mcp-adapters, chromadb, langchain-classic, langchain-chroma, langchain-community
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.4
#     Uninstalling requests-2.32.4:
#       Successfully uninstalled requests-2.32.4
#   Attempting uninstall: opentelemetry-api
#     Found existing installation: opentelemetry-api 1.42.1
#     Uninstalling opentelemetry-api-1.42.1:
#       Successfully uninstalled opentelemetry-api-1.42.1
#   Attempting uninstall: opentelemetry-semantic-conventions
#     Found existing installation: opentelemetry-semantic-conventions 0.63b1
#     Uninstalling opentelemetry-semantic-conventions-0.63b1:
#       Successfully uninstalled opentelemetry-semantic-conventions-0.63b1
#   Attempting uninstall: opentelemetry-sdk
#     Found existing installation: opentelemetry-sdk 1.42.1
#     Uninstalling opentelemetry-sdk-1.42.1:
#       Successfully uninstalled opentelemetry-sdk-1.42.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.34.2 which is incompatible.
# google-adk 2.4.0 requires opentelemetry-api<=1.42.1,>=1.39, but you have opentelemetry-api 1.44.0 which is incompatible.
# google-adk 2.4.0 requires opentelemetry-sdk<=1.42.1,>=1.39, but you have opentelemetry-sdk 1.44.0 which is incompatible.
# Successfully installed bcrypt-5.0.0 build-1.5.0 chromadb-1.5.9 durationpy-0.10 httpx-sse-0.4.3 kubernetes-36.0.3 langchain-chroma-1.1.0 langchain-classic-1.0.8 langchain-community-0.4.2 langchain-mcp-adapters-0.3.2 langchain-openai-1.5.1 langchain-text-splitters-1.1.2 mcp-1.29.0 onnxruntime-1.28.0 opentelemetry-api-1.44.0 opentelemetry-exporter-otlp-proto-common-1.44.0 opentelemetry-exporter-otlp-proto-grpc-1.44.0 opentelemetry-proto-1.44.0 opentelemetry-sdk-1.44.0 opentelemetry-semantic-conventions-0.65b0 overrides-7.7.0 pybase64-1.5.0 pydantic-settings-2.15.0 pypdf-6.16.1 pypika-0.51.1 pyproject_hooks-1.2.0 requests-2.34.2 sse-starlette-3.4.8

# %%
# !pip install langchain-anthropic
# Out:
# Collecting langchain-anthropic
#   Downloading langchain_anthropic-1.5.6-py3-none-any.whl.metadata (3.5 kB)
# Collecting anthropic<1.0.0,>=0.120.0 (from langchain-anthropic)
#   Downloading anthropic-0.122.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.5.4 in /usr/local/lib/python3.12/dist-packages (from langchain-anthropic) (1.5.5)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.12/dist-packages (from langchain-anthropic) (2.13.4)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from anthropic<1.0.0,>=0.120.0->langchain-anthropic) (4.14.2)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from anthropic<1.0.0,>=0.120.0->langchain-anthropic) (1.9.0)
# Requirement already satisfied: docstring-parser<1,>=0.15 in /usr/local/lib/python3.12/dist-packages (from anthropic<1.0.0,>=0.120.0->langchain-anthropic) (0.18.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from anthropic<1.0.0,>=0.120.0->langchain-anthropic) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from anthropic<1.0.0,>=0.120.0->langchain-anthropic) (0.16.0)
# Requirement already satisfied: sniffio<2,>=1 in /usr/local/lib/python3.12/dist-packages (from anthropic<1.0.0,>=0.120.0->langchain-anthropic) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.14 in /usr/local/lib/python3.12/dist-packages (from anthropic<1.0.0,>=0.120.0->langchain-anthropic) (4.16.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.5.4->langchain-anthropic) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.5.4->langchain-anthropic) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.5.4->langchain-anthropic) (0.10.2)
# Requirement already satisfied: packaging>=23.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.5.4->langchain-anthropic) (26.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.5.4->langchain-anthropic) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.5.4->langchain-anthropic) (9.1.4)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.5.4->langchain-anthropic) (0.17.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-anthropic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-anthropic) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-anthropic) (0.4.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->anthropic<1.0.0,>=0.120.0->langchain-anthropic) (3.18)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.25.0->anthropic<1.0.0,>=0.120.0->langchain-anthropic) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.25.0->anthropic<1.0.0,>=0.120.0->langchain-anthropic) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.25.0->anthropic<1.0.0,>=0.120.0->langchain-anthropic) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.5.4->langchain-anthropic) (3.1.1)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.5.4->langchain-anthropic) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.5.4->langchain-anthropic) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.5.4->langchain-anthropic) (2.34.2)
# Requirement already satisfied: websockets>=15.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.5.4->langchain-anthropic) (15.0.1)
# Requirement already satisfied: xxhash>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.5.4->langchain-anthropic) (3.8.1)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.5.4->langchain-anthropic) (0.25.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.5.4->langchain-anthropic) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.26 in /usr/local/lib/python3.12/dist-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.5.4->langchain-anthropic) (2.5.0)
# Downloading langchain_anthropic-1.5.6-py3-none-any.whl (56 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 kB 2.7 MB/s eta 0:00:00
# Downloading anthropic-0.122.0-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 20.3 MB/s eta 0:00:00
# Installing collected packages: anthropic, langchain-anthropic
# Successfully installed anthropic-0.122.0 langchain-anthropic-1.5.6

# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# False

# %%
from google.colab import userdata
os.environ['ANTHROPIC_API_KEY'] = userdata.get('ANTHROPIC_API_KEY')

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model('anthropic:claude-sonnet-4-6')
model.invoke('Hi')
print("Cinebot's Brain is connected")
# Out:
# Cinebot's Brain is connected

# %%
import os
os.getcwd()
# Out:
# '/content'

# %%
from langchain.agents.middleware import ShellToolMiddleware, HostExecutionPolicy

# %%
from langchain.chat_models import init_chat_model
from langchain.agents import create_agent

# %%
cinebot_shell_agent = create_agent(
    model=model,
    tools=[],
    middleware=[
        ShellToolMiddleware(
            workspace_root="/content/cinebot_workspace",  # a real Colab path -- swap for /tmp/... if running elsewhere
            execution_policy=HostExecutionPolicy(),
        ),
    ],
)

# %%
cinebot_shell_agent

# %%
from rich import print

# %%
result = cinebot_shell_agent.invoke({"messages": [("user", "Create a reports folder if the same doesn't exist.")]})

# %%
result = cinebot_shell_agent.invoke({"messages": [("user", "Do a Research on NBA and save it in a file nba_research.txt.")]})

# %%
print(result)
# Out:
# {
#     'messages': [
#         HumanMessage(
#             content='Do a Research on NBA and save it in a file nba_research.txt.',
#             additional_kwargs={},
#             response_metadata={},
#             id='c0fe7dd6-0f0e-4905-b23a-c78d66162467'
#         ),
#         AIMessage(
#             content=[
#                 {
#                     'id': 'toolu_01Fdijz8rnsMps5i7Ct7rtSj',
#                     'caller': {'type': 'direct'},
#                     'input': {
#                         'command': 'cat << \'EOF\' >
# nba_research.txt\n=============================================================\n         COMPREHENSIVE RESEARCH ON
# THE NBA\n         (National Basketball
# Association)\n=============================================================\n\n------------------------------------
# -------------------------\n1. OVERVIEW\n-------------------------------------------------------------\nThe National
# Basketball Association (NBA) is the premier\nprofessional basketball league in the world. It is a major\nNorth
# American professional sports league and is widely\nconsidered the top professional basketball league globally.\n\n-
# Full Name    : National Basketball Association\n- Founded      : June 6, 1946 (as BAA), renamed NBA in 1949\n-
# Headquarters : New York City, New York, USA\n- Commissioner : Adam Silver (since February 2014)\n- No. of Teams :
# 30 teams (29 in the USA, 1 in Canada)\n- Seasons      : October – June (Regular Season +
# Playoffs)\n\n-------------------------------------------------------------\n2.
# HISTORY\n-------------------------------------------------------------\n- 1946: The Basketball Association of
# America (BAA) was\n        founded by arena owners in major cities.\n- 1949: The BAA merged with the National
# Basketball League\n        (NBL) to form the NBA.\n- 1950: Chuck Cooper became the first African American\n
# player drafted in the NBA.\n- 1954: The 24-second shot clock was introduced, speeding\n        up the pace of the
# game.\n- 1967: The rival American Basketball Association (ABA)\n        was formed.\n- 1976: The NBA merged with
# the ABA, absorbing 4 teams.\n- 1979: The 3-point line was introduced.\n- 1984: David Stern became Commissioner,
# launching a new\n        era of global NBA growth.\n- 1992: The "Dream Team" represented the USA at the\n
# Barcelona Olympics, globalizing the sport.\n- 2014: Adam Silver succeeded David Stern as Commissioner.\n- 2019: The
# NBA launched the NBA G League Ignite for\n        elite
# prospects.\n\n-------------------------------------------------------------\n3. STRUCTURE &
# CONFERENCES\n-------------------------------------------------------------\nThe NBA is divided into 2 Conferences,
# each with 3 Divisions:\n\n  EASTERN CONFERENCE:\n  ├── Atlantic Division\n  │     • Boston Celtics\n  │     •
# Brooklyn Nets\n  │     • New York Knicks\n  │     • Philadelphia 76ers\n  │     • Toronto Raptors\n  ├── Central
# Division\n  │     • Chicago Bulls\n  │     • Cleveland Cavaliers\n  │     • Detroit Pistons\n  │     • Indiana
# Pacers\n  │     • Milwaukee Bucks\n  └── Southeast Division\n        • Atlanta Hawks\n        • Charlotte Hornets\n
# • Miami Heat\n        • Orlando Magic\n        • Washington Wizards\n\n  WESTERN CONFERENCE:\n  ├── Northwest
# Division\n  │     • Denver Nuggets\n  │     • Minnesota Timberwolves\n  │     • Oklahoma City Thunder\n  │     •
# Portland Trail Blazers\n  │     • Utah Jazz\n  ├── Pacific Division\n  │     • Golden State Warriors\n  │     • Los
# Angeles Clippers\n  │     • Los Angeles Lakers\n  │     • Phoenix Suns\n  │     • Sacramento Kings\n  └── Southwest
# Division\n        • Dallas Mavericks\n        • Houston Rockets\n        • Memphis Grizzlies\n        • New Orleans
# Pelicans\n        • San Antonio Spurs\n\n-------------------------------------------------------------\n4. SEASON
# FORMAT\n-------------------------------------------------------------\n- Regular Season : 82 games per team
# (October – April)\n- Play-In Tournament: 7th–10th seed teams compete for\n                      the final playoff
# spots\n- Playoffs       : 16 teams (8 per conference), best-of-7\n                   series, single-elimination
# bracket style\n- NBA Finals     : Best-of-7 series between Eastern and\n                   Western Conference
# Champions (June)\n\n-------------------------------------------------------------\n5. ALL-TIME NBA
# CHAMPIONS\n-------------------------------------------------------------\nMost Championships by Franchise:\n  🏆
# Boston Celtics         – 17 titles\n  🏆 Los Angeles Lakers     – 17 titles\n  🏆 Golden State Warriors  – 7
# titles\n  🏆 Chicago Bulls          – 6 titles\n  🏆 San Antonio Spurs      – 5 titles\n  🏆 Miami Heat
# – 3 titles\n  🏆 Detroit Pistons        – 3 titles\n  🏆 Philadelphia 76ers     – 3 titles\n  🏆 New York Knicks
# – 2 titles\n\nRecent NBA Champions:\n  2024 – Boston Celtics\n  2023 – Denver Nuggets\n  2022 – Golden State
# Warriors\n  2021 – Milwaukee Bucks\n  2020 – Los Angeles Lakers\n  2019 – Toronto Raptors\n  2018 – Golden State
# Warriors\n  2017 – Golden State Warriors\n  2016 – Cleveland Cavaliers\n  2015 – Golden State
# Warriors\n\n-------------------------------------------------------------\n6. LEGENDARY PLAYERS (ALL-TIME
# GREATS)\n-------------------------------------------------------------\n┌─────────────────────┬────────────────────
# ──────┬────────────┐\n│ Player              │ Team(s)                  │ Titles
# │\n├─────────────────────┼──────────────────────────┼────────────┤\n│ Michael Jordan      │ Bulls, Wizards
# │ 6          │\n│ LeBron James        │ Cavaliers, Heat, Lakers   │ 4          │\n│ Kareem Abdul-Jabbar │ Bucks,
# Lakers             │ 6          │\n│ Magic Johnson       │ Lakers                   │ 5          │\n│ Larry Bird
# │ Celtics                  │ 3          │\n│ Wilt Chamberlain    │ Warriors, 76ers, Lakers  │ 2          │\n│ Bill
# Russell        │ Celtics                  │ 11         │\n│ Shaquille O\'Neal    │ Lakers, Heat, others     │ 4
# │\n│ Kobe Bryant         │ Lakers                   │ 5          │\n│ Tim Duncan          │ Spurs
# │ 5          │\n│ Stephen Curry       │ Warriors                 │ 4          │\n│ Kevin Durant        │ Thunder,
# Warriors, others│ 2
# │\n└─────────────────────┴──────────────────────────┴────────────┘\n\n---------------------------------------------
# ----------------\n7. KEY AWARDS & TROPHIES\n-------------------------------------------------------------\n- NBA
# Most Valuable Player (MVP)         – Regular Season\n- NBA Finals MVP                         – Playoffs\n- NBA
# Defensive Player of the Year       – Best Defender\n- NBA Rookie of the Year                 – Best New Player\n-
# NBA Sixth Man of the Year              – Best Reserve\n- NBA Most Improved Player               – Biggest Growth\n-
# NBA Coach of the Year                  – Best Coach\n- NBA All-Star Game MVP                  – All-Star Weekend\n-
# NBA Scoring Champion                   – Top Points/Game\n- NBA All-Defensive Team (1st & 2nd)     – Top
# Defenders\n- NBA All-NBA Team (1st, 2nd & 3rd)      – Top
# Players\n\n-------------------------------------------------------------\n8. ALL-TIME STATISTICAL
# LEADERS\n-------------------------------------------------------------\nPoints (All-Time):\n  1. LeBron James
# – 40,000+ points (Active)\n  2. Kareem Abdul-Jabbar  – 38,387 points\n  3. Karl Malone          – 36,928 points\n
# 4. Kobe Bryant          – 33,643 points\n  5. Michael Jordan       – 32,292 points\n\nAssists (All-Time):\n  1.
# John Stockton        – 15,806 assists\n  2. Jason Kidd           – 12,091 assists\n  3. Steve Nash           –
# 10,335 assists\n\nRebounds (All-Time):\n  1. Wilt Chamberlain     – 23,924 rebounds\n  2. Bill Russell         –
# 21,620 rebounds\n  3. Kareem Abdul-Jabbar  – 17,440 rebounds\n\nSingle-Game Records:\n  • Most Points in a Game :
# Wilt Chamberlain – 100 pts (1962)\n  • Most Assists in a Game: Scott Skiles – 30 assists (1990)\n  • Most Rebounds
# in Game : Wilt Chamberlain – 55 rebounds\n\n-------------------------------------------------------------\n9. THE
# NBA DRAFT\n-------------------------------------------------------------\n- Held annually (usually in June)\n- 2
# rounds, 60 picks total (30 per round)\n- Teams select eligible players (college, international)\n- The Draft
# Lottery determines the top pick order for\n  non-playoff teams\n- Notable #1 Overall Picks:\n    • 1984 – Hakeem
# Olajuwon\n    • 1992 – Shaquille O\'Neal\n    • 2003 – LeBron James\n    • 2012 – Anthony Davis\n    • 2019 – Zion
# Williamson\n    • 2023 – Victor Wembanyama\n\n-------------------------------------------------------------\n10.
# THE NBA GLOBALLY\n-------------------------------------------------------------\n- Broadcast in over 215 countries
# and territories\n- Games televised in 50+ languages\n- International players make up ~25% of all NBA rosters\n- NBA
# Africa: Established to grow the game in Africa\n- NBA India, NBA China: Regional offices and academies\n- NBA
# Global Games: Regular season games played abroad\n  (Paris, London, Mexico City, Tokyo, Abu Dhabi)\n- Social Media
# Following: 150M+ across all platforms\n\n-------------------------------------------------------------\n11. NBA G
# LEAGUE (DEVELOPMENT LEAGUE)\n-------------------------------------------------------------\n- Founded in 2001 as
# the NBDL\n- Renamed NBA G League in 2017 (sponsored by Gatorade)\n- 30 teams affiliated with NBA franchises\n-
# Serves as the primary development league for the NBA\n- Players can be called up to NBA rosters at any
# time\n\n-------------------------------------------------------------\n12. NBA BUSINESS &
# FINANCIALS\n-------------------------------------------------------------\n- League Valuation     : ~$10 billion+
# (entire league)\n- Highest Valued Team  : Golden State Warriors (~$7B+)\n- NBA Media Deal       : $76 Billion deal
# with ESPN/ABC\n                         and Amazon (2025–2036)\n- Salary Cap (2024-25) : ~$140.6 million per
# team\n- Average Player Salary: ~$10 million per year\n- Highest Paid Players : Steph Curry, LeBron James,\n
# Kevin Durant (~$50M+/year)\n- Revenue (Annual)     : ~$10
# billion+\n\n-------------------------------------------------------------\n13. NBA CULTURE &
# IMPACT\n-------------------------------------------------------------\n- Fashion: NBA players are global fashion
# icons; "Tunnel\n  Walks" are widely followed on social media.\n- Music: Deep ties with hip-hop culture; many
# players have\n  music careers or label ownership.\n- Social Justice: NBA players and the league are active in\n
# social justice causes (e.g., BLM movement in 2020,\n  voting rights campaigns).\n- Technology: NBA leads in sports
# tech — player tracking,\n  AI analytics, virtual/augmented reality broadcasts.\n- Community: NBA Cares program has
# donated millions of\n  hours and dollars to communities
# worldwide.\n\n-------------------------------------------------------------\n14. FUN
# FACTS\n-------------------------------------------------------------\n  ✔ The NBA basketball is 29.5 inches in
# circumference.\n  ✔ An NBA court is 94 feet long and 50 feet wide.\n  ✔ The 3-point line ranges from 22 ft
# (corners) to\n    23 ft 9 in (top of the arc).\n  ✔ An NBA game consists of 4 quarters of 12 minutes each.\n  ✔ The
# shot clock is 24 seconds.\n  ✔ Bill Russell won 11 championships in 13 seasons —\n    the most dominant run in NBA
# history.\n  ✔ Wilt Chamberlain averaged 50.4 points per game in the\n    1961–62 season — a record that still
# stands.\n  ✔ The NBA All-Star Weekend includes the Dunk Contest,\n    3-Point Contest, and Skills Challenge.\n  ✔
# The Toronto Raptors (Canada) are the only non-US
# team.\n\n-------------------------------------------------------------\n15. FUTURE OF THE
# NBA\n-------------------------------------------------------------\n- Expansion Teams: Las Vegas and Seattle are
# top candidates\n  for new NBA franchises.\n- New Media Rights: Streaming and digital-first broadcasting\n  is the
# future of NBA media.\n- Global Expansion: Potential for international NBA games\n  and even international
# franchises.\n- Technology: AI-driven coaching tools, smart arenas, and\n  immersive fan experiences (VR/AR).\n-
# Youth Development: NBA Academies worldwide continue to\n  scout and develop global
# talent.\n\n=============================================================\n         END OF NBA RESEARCH
# DOCUMENT\n=============================================================\nEOF\necho "File created successfully!"'
#                     },
#                     'name': 'shell',
#                     'type': 'tool_use'
#                 }
#             ],
#             additional_kwargs={},
#             response_metadata={
#                 'id': 'msg_011Ce5hrGS8c3T99K6wzvtMN',
#                 'container': None,
#                 'model': 'claude-sonnet-4-6',
#                 'stop_details': None,
#                 'stop_reason': 'tool_use',
#                 'stop_sequence': None,
#                 'usage': {
#                     'cache_creation': {'ephemeral_1h_input_tokens': 0, 'ephemeral_5m_input_tokens': 0},
#                     'cache_creation_input_tokens': 0,
#                     'cache_read_input_tokens': 0,
#                     'inference_geo': 'global',
#                     'input_tokens': 729,
#                     'output_tokens': 3116,
#                     'output_tokens_details': None,
#                     'server_tool_use': None,
#                     'service_tier': 'standard'
#                 },
#                 'model_name': 'claude-sonnet-4-6',
#                 'model_provider': 'anthropic'
#             },
#             id='lc_run--01a00894-71ed-78d1-af95-2e47eb01db3c-0',
#             tool_calls=[
#                 {
#                     'name': 'shell',
#                     'args': {
#                         'command': 'cat << \'EOF\' >
# nba_research.txt\n=============================================================\n         COMPREHENSIVE RESEARCH ON
# THE NBA\n         (National Basketball
# Association)\n=============================================================\n\n------------------------------------
# -------------------------\n1. OVERVIEW\n-------------------------------------------------------------\nThe National
# Basketball Association (NBA) is the premier\nprofessional basketball league in the world. It is a major\nNorth
# American professional sports league and is widely\nconsidered the top professional basketball league globally.\n\n-
# Full Name    : National Basketball Association\n- Founded      : June 6, 1946 (as BAA), renamed NBA in 1949\n-
# Headquarters : New York City, New York, USA\n- Commissioner : Adam Silver (since February 2014)\n- No. of Teams :
# 30 teams (29 in the USA, 1 in Canada)\n- Seasons      : October – June (Regular Season +
# Playoffs)\n\n-------------------------------------------------------------\n2.
# HISTORY\n-------------------------------------------------------------\n- 1946: The Basketball Association of
# America (BAA) was\n        founded by arena owners in major cities.\n- 1949: The BAA merged with the National
# Basketball League\n        (NBL) to form the NBA.\n- 1950: Chuck Cooper became the first African American\n
# player drafted in the NBA.\n- 1954: The 24-second shot clock was introduced, speeding\n        up the pace of the
# game.\n- 1967: The rival American Basketball Association (ABA)\n        was formed.\n- 1976: The NBA merged with
# the ABA, absorbing 4 teams.\n- 1979: The 3-point line was introduced.\n- 1984: David Stern became Commissioner,
# launching a new\n        era of global NBA growth.\n- 1992: The "Dream Team" represented the USA at the\n
# Barcelona Olympics, globalizing the sport.\n- 2014: Adam Silver succeeded David Stern as Commissioner.\n- 2019: The
# NBA launched the NBA G League Ignite for\n        elite
# prospects.\n\n-------------------------------------------------------------\n3. STRUCTURE &
# CONFERENCES\n-------------------------------------------------------------\nThe NBA is divided into 2 Conferences,
# each with 3 Divisions:\n\n  EASTERN CONFERENCE:\n  ├── Atlantic Division\n  │     • Boston Celtics\n  │     •
# Brooklyn Nets\n  │     • New York Knicks\n  │     • Philadelphia 76ers\n  │     • Toronto Raptors\n  ├── Central
# Division\n  │     • Chicago Bulls\n  │     • Cleveland Cavaliers\n  │     • Detroit Pistons\n  │     • Indiana
# Pacers\n  │     • Milwaukee Bucks\n  └── Southeast Division\n        • Atlanta Hawks\n        • Charlotte Hornets\n
# • Miami Heat\n        • Orlando Magic\n        • Washington Wizards\n\n  WESTERN CONFERENCE:\n  ├── Northwest
# Division\n  │     • Denver Nuggets\n  │     • Minnesota Timberwolves\n  │     • Oklahoma City Thunder\n  │     •
# Portland Trail Blazers\n  │     • Utah Jazz\n  ├── Pacific Division\n  │     • Golden State Warriors\n  │     • Los
# Angeles Clippers\n  │     • Los Angeles Lakers\n  │     • Phoenix Suns\n  │     • Sacramento Kings\n  └── Southwest
# Division\n        • Dallas Mavericks\n        • Houston Rockets\n        • Memphis Grizzlies\n        • New Orleans
# Pelicans\n        • San Antonio Spurs\n\n-------------------------------------------------------------\n4. SEASON
# FORMAT\n-------------------------------------------------------------\n- Regular Season : 82 games per team
# (October – April)\n- Play-In Tournament: 7th–10th seed teams compete for\n                      the final playoff
# spots\n- Playoffs       : 16 teams (8 per conference), best-of-7\n                   series, single-elimination
# bracket style\n- NBA Finals     : Best-of-7 series between Eastern and\n                   Western Conference
# Champions (June)\n\n-------------------------------------------------------------\n5. ALL-TIME NBA
# CHAMPIONS\n-------------------------------------------------------------\nMost Championships by Franchise:\n  🏆
# Boston Celtics         – 17 titles\n  🏆 Los Angeles Lakers     – 17 titles\n  🏆 Golden State Warriors  – 7
# titles\n  🏆 Chicago Bulls          – 6 titles\n  🏆 San Antonio Spurs      – 5 titles\n  🏆 Miami Heat
# – 3 titles\n  🏆 Detroit Pistons        – 3 titles\n  🏆 Philadelphia 76ers     – 3 titles\n  🏆 New York Knicks
# – 2 titles\n\nRecent NBA Champions:\n  2024 – Boston Celtics\n  2023 – Denver Nuggets\n  2022 – Golden State
# Warriors\n  2021 – Milwaukee Bucks\n  2020 – Los Angeles Lakers\n  2019 – Toronto Raptors\n  2018 – Golden State
# Warriors\n  2017 – Golden State Warriors\n  2016 – Cleveland Cavaliers\n  2015 – Golden State
# Warriors\n\n-------------------------------------------------------------\n6. LEGENDARY PLAYERS (ALL-TIME
# GREATS)\n-------------------------------------------------------------\n┌─────────────────────┬────────────────────
# ──────┬────────────┐\n│ Player              │ Team(s)                  │ Titles
# │\n├─────────────────────┼──────────────────────────┼────────────┤\n│ Michael Jordan      │ Bulls, Wizards
# │ 6          │\n│ LeBron James        │ Cavaliers, Heat, Lakers   │ 4          │\n│ Kareem Abdul-Jabbar │ Bucks,
# Lakers             │ 6          │\n│ Magic Johnson       │ Lakers                   │ 5          │\n│ Larry Bird
# │ Celtics                  │ 3          │\n│ Wilt Chamberlain    │ Warriors, 76ers, Lakers  │ 2          │\n│ Bill
# Russell        │ Celtics                  │ 11         │\n│ Shaquille O\'Neal    │ Lakers, Heat, others     │ 4
# │\n│ Kobe Bryant         │ Lakers                   │ 5          │\n│ Tim Duncan          │ Spurs
# │ 5          │\n│ Stephen Curry       │ Warriors                 │ 4          │\n│ Kevin Durant        │ Thunder,
# Warriors, others│ 2
# │\n└─────────────────────┴──────────────────────────┴────────────┘\n\n---------------------------------------------
# ----------------\n7. KEY AWARDS & TROPHIES\n-------------------------------------------------------------\n- NBA
# Most Valuable Player (MVP)         – Regular Season\n- NBA Finals MVP                         – Playoffs\n- NBA
# Defensive Player of the Year       – Best Defender\n- NBA Rookie of the Year                 – Best New Player\n-
# NBA Sixth Man of the Year              – Best Reserve\n- NBA Most Improved Player               – Biggest Growth\n-
# NBA Coach of the Year                  – Best Coach\n- NBA All-Star Game MVP                  – All-Star Weekend\n-
# NBA Scoring Champion                   – Top Points/Game\n- NBA All-Defensive Team (1st & 2nd)     – Top
# Defenders\n- NBA All-NBA Team (1st, 2nd & 3rd)      – Top
# Players\n\n-------------------------------------------------------------\n8. ALL-TIME STATISTICAL
# LEADERS\n-------------------------------------------------------------\nPoints (All-Time):\n  1. LeBron James
# – 40,000+ points (Active)\n  2. Kareem Abdul-Jabbar  – 38,387 points\n  3. Karl Malone          – 36,928 points\n
# 4. Kobe Bryant          – 33,643 points\n  5. Michael Jordan       – 32,292 points\n\nAssists (All-Time):\n  1.
# John Stockton        – 15,806 assists\n  2. Jason Kidd           – 12,091 assists\n  3. Steve Nash           –
# 10,335 assists\n\nRebounds (All-Time):\n  1. Wilt Chamberlain     – 23,924 rebounds\n  2. Bill Russell         –
# 21,620 rebounds\n  3. Kareem Abdul-Jabbar  – 17,440 rebounds\n\nSingle-Game Records:\n  • Most Points in a Game :
# Wilt Chamberlain – 100 pts (1962)\n  • Most Assists in a Game: Scott Skiles – 30 assists (1990)\n  • Most Rebounds
# in Game : Wilt Chamberlain – 55 rebounds\n\n-------------------------------------------------------------\n9. THE
# NBA DRAFT\n-------------------------------------------------------------\n- Held annually (usually in June)\n- 2
# rounds, 60 picks total (30 per round)\n- Teams select eligible players (college, international)\n- The Draft
# Lottery determines the top pick order for\n  non-playoff teams\n- Notable #1 Overall Picks:\n    • 1984 – Hakeem
# Olajuwon\n    • 1992 – Shaquille O\'Neal\n    • 2003 – LeBron James\n    • 2012 – Anthony Davis\n    • 2019 – Zion
# Williamson\n    • 2023 – Victor Wembanyama\n\n-------------------------------------------------------------\n10.
# THE NBA GLOBALLY\n-------------------------------------------------------------\n- Broadcast in over 215 countries
# and territories\n- Games televised in 50+ languages\n- International players make up ~25% of all NBA rosters\n- NBA
# Africa: Established to grow the game in Africa\n- NBA India, NBA China: Regional offices and academies\n- NBA
# Global Games: Regular season games played abroad\n  (Paris, London, Mexico City, Tokyo, Abu Dhabi)\n- Social Media
# Following: 150M+ across all platforms\n\n-------------------------------------------------------------\n11. NBA G
# LEAGUE (DEVELOPMENT LEAGUE)\n-------------------------------------------------------------\n- Founded in 2001 as
# the NBDL\n- Renamed NBA G League in 2017 (sponsored by Gatorade)\n- 30 teams affiliated with NBA franchises\n-
# Serves as the primary development league for the NBA\n- Players can be called up to NBA rosters at any
# time\n\n-------------------------------------------------------------\n12. NBA BUSINESS &
# FINANCIALS\n-------------------------------------------------------------\n- League Valuation     : ~$10 billion+
# (entire league)\n- Highest Valued Team  : Golden State Warriors (~$7B+)\n- NBA Media Deal       : $76 Billion deal
# with ESPN/ABC\n                         and Amazon (2025–2036)\n- Salary Cap (2024-25) : ~$140.6 million per
# team\n- Average Player Salary: ~$10 million per year\n- Highest Paid Players : Steph Curry, LeBron James,\n
# Kevin Durant (~$50M+/year)\n- Revenue (Annual)     : ~$10
# billion+\n\n-------------------------------------------------------------\n13. NBA CULTURE &
# IMPACT\n-------------------------------------------------------------\n- Fashion: NBA players are global fashion
# icons; "Tunnel\n  Walks" are widely followed on social media.\n- Music: Deep ties with hip-hop culture; many
# players have\n  music careers or label ownership.\n- Social Justice: NBA players and the league are active in\n
# social justice causes (e.g., BLM movement in 2020,\n  voting rights campaigns).\n- Technology: NBA leads in sports
# tech — player tracking,\n  AI analytics, virtual/augmented reality broadcasts.\n- Community: NBA Cares program has
# donated millions of\n  hours and dollars to communities
# worldwide.\n\n-------------------------------------------------------------\n14. FUN
# FACTS\n-------------------------------------------------------------\n  ✔ The NBA basketball is 29.5 inches in
# circumference.\n  ✔ An NBA court is 94 feet long and 50 feet wide.\n  ✔ The 3-point line ranges from 22 ft
# (corners) to\n    23 ft 9 in (top of the arc).\n  ✔ An NBA game consists of 4 quarters of 12 minutes each.\n  ✔ The
# shot clock is 24 seconds.\n  ✔ Bill Russell won 11 championships in 13 seasons —\n    the most dominant run in NBA
# history.\n  ✔ Wilt Chamberlain averaged 50.4 points per game in the\n    1961–62 season — a record that still
# stands.\n  ✔ The NBA All-Star Weekend includes the Dunk Contest,\n    3-Point Contest, and Skills Challenge.\n  ✔
# The Toronto Raptors (Canada) are the only non-US
# team.\n\n-------------------------------------------------------------\n15. FUTURE OF THE
# NBA\n-------------------------------------------------------------\n- Expansion Teams: Las Vegas and Seattle are
# top candidates\n  for new NBA franchises.\n- New Media Rights: Streaming and digital-first broadcasting\n  is the
# future of NBA media.\n- Global Expansion: Potential for international NBA games\n  and even international
# franchises.\n- Technology: AI-driven coaching tools, smart arenas, and\n  immersive fan experiences (VR/AR).\n-
# Youth Development: NBA Academies worldwide continue to\n  scout and develop global
# talent.\n\n=============================================================\n         END OF NBA RESEARCH
# DOCUMENT\n=============================================================\nEOF\necho "File created successfully!"'
#                     },
#                     'id': 'toolu_01Fdijz8rnsMps5i7Ct7rtSj',
#                     'type': 'tool_call'
#                 }
#             ],
#             invalid_tool_calls=[],
#             usage_metadata={
#                 'input_tokens': 729,
#                 'output_tokens': 3116,
#                 'total_tokens': 3845,
#                 'input_token_details': {
#                     'cache_read': 0,
#                     'cache_creation': 0,
#                     'ephemeral_5m_input_tokens': 0,
#                     'ephemeral_1h_input_tokens': 0
#                 }
#             }
#         ),
#         ToolMessage(
#             content='File created successfully!\n',
#             name='shell',
#             id='878fd6d5-a4ee-4063-ae99-f449139c7981',
#             tool_call_id='toolu_01Fdijz8rnsMps5i7Ct7rtSj',
#             artifact={
#                 'timed_out': False,
#                 'exit_code': 0,
#                 'truncated_by_lines': False,
#                 'truncated_by_bytes': False,
#                 'total_lines': 1,
#                 'total_bytes': 27,
#                 'redaction_matches': {}
#             }
#         ),
#         AIMessage(
#             content=[
#                 {
#                     'id': 'toolu_018HC6nTLzm7Ngqkx2dH5j8B',
#                     'caller': {'type': 'direct'},
#                     'input': {'command': 'cat nba_research.txt'},
#                     'name': 'shell',
#                     'type': 'tool_use'
#                 }
#             ],
#             additional_kwargs={},
#             response_metadata={
#                 'id': 'msg_011Ce5hvDriBCL5mcVpqDjCY',
#                 'container': None,
#                 'model': 'claude-sonnet-4-6',
#                 'stop_details': None,
#                 'stop_reason': 'tool_use',
#                 'stop_sequence': None,
#                 'usage': {
#                     'cache_creation': {'ephemeral_1h_input_tokens': 0, 'ephemeral_5m_input_tokens': 0},
#                     'cache_creation_input_tokens': 0,
#                     'cache_read_input_tokens': 0,
#                     'inference_geo': 'global',
#                     'input_tokens': 3862,
#                     'output_tokens': 57,
#                     'output_tokens_details': None,
#                     'server_tool_use': None,
#                     'service_tier': 'standard'
#                 },
#                 'model_name': 'claude-sonnet-4-6',
#                 'model_provider': 'anthropic'
#             },
#             id='lc_run--01a00895-4375-7c73-a4b1-79bb65d7fa1a-0',
#             tool_calls=[
#                 {
#                     'name': 'shell',
#                     'args': {'command': 'cat nba_research.txt'},
#                     'id': 'toolu_018HC6nTLzm7Ngqkx2dH5j8B',
#                     'type': 'tool_call'
#                 }
#             ],
#             invalid_tool_calls=[],
#             usage_metadata={
#                 'input_tokens': 3862,
#                 'output_tokens': 57,
#                 'total_tokens': 3919,
#                 'input_token_details': {
#                     'cache_read': 0,
#                     'cache_creation': 0,
#                     'ephemeral_5m_input_tokens': 0,
#                     'ephemeral_1h_input_tokens': 0
#                 }
#             }
#         ),
#         ToolMessage(
#             content='=============================================================\n         COMPREHENSIVE RESEARCH
# ON THE NBA\n         (National Basketball
# Association)\n=============================================================\n\n------------------------------------
# -------------------------\n1. OVERVIEW\n-------------------------------------------------------------\nThe National
# Basketball Association (NBA) is the premier\nprofessional basketball league in the world. It is a major\nNorth
# American professional sports league and is widely\nconsidered the top professional basketball league globally.\n\n-
# Full Name    : National Basketball Association\n- Founded      : June 6, 1946 (as BAA), renamed NBA in 1949\n-
# Headquarters : New York City, New York, USA\n- Commissioner : Adam Silver (since February 2014)\n- No. of Teams :
# 30 teams (29 in the USA, 1 in Canada)\n- Seasons      : October – June (Regular Season +
# Playoffs)\n\n-------------------------------------------------------------\n2.
# HISTORY\n-------------------------------------------------------------\n- 1946: The Basketball Association of
# America (BAA) was\n        founded by arena owners in major cities.\n- 1949: The BAA merged with the National
# Basketball League\n        (NBL) to form the NBA.\n- 1950: Chuck Cooper became the first African American\n
# player drafted in the NBA.\n- 1954: The 24-second shot clock was introduced, speeding\n        up the pace of the
# game.\n- 1967: The rival American Basketball Association (ABA)\n        was formed.\n- 1976: The NBA merged with
# the ABA, absorbing 4 teams.\n- 1979: The 3-point line was introduced.\n- 1984: David Stern became Commissioner,
# launching a new\n        era of global NBA growth.\n- 1992: The "Dream Team" represented the USA at the\n
# Barcelona Olympics, globalizing the sport.\n- 2014: Adam Silver succeeded David Stern as Commissioner.\n- 2019: The
# NBA launched the NBA G League Ignite for\n        elite
# prospects.\n\n-------------------------------------------------------------\n3. STRUCTURE &
# CONFERENCES\n-------------------------------------------------------------\nThe NBA is divided into 2 Conferences,
# each with 3 Divisions:\n\n  EASTERN CONFERENCE:\n  ├── Atlantic Division\n  │     • Boston Celtics\n  │     •
# Brooklyn Nets\n  │     • New York Knicks\n  │     • Philadelphia 76ers\n  │     • Toronto Raptors\n  ├── Central
# Division\n  │     • Chicago Bulls\n  │     • Cleveland Cavaliers\n  │     • Detroit Pistons\n  │     • Indiana
# Pacers\n  │     • Milwaukee Bucks\n  └── Southeast Division\n        • Atlanta Hawks\n        • Charlotte Hornets\n
# • Miami Heat\n        • Orlando Magic\n        • Washington Wizards\n\n  WESTERN CONFERENCE:\n  ├── Northwest
# Division\n  │     • Denver Nuggets\n  │     • Minnesota Timberwolves\n  │     • Oklahoma City Thunder\n  │     •
# Portland Trail Blazers\n  │     • Utah Jazz\n  ├── Pacific Division\n  │     • Golden State Warriors\n  │     • Los
# Angeles Clippers\n  │     • Los Angeles Lakers\n  │     • Phoenix Suns\n  │     • Sacramento Kings\n  └── Southwest
# Division\n        • Dallas Mavericks\n        • Houston Rockets\n        • Memphis Grizzlies\n        • New Orleans
# Pelicans\n        • San Antonio Spurs\n\n-------------------------------------------------------------\n4. SEASON
# FORMAT\n-------------------------------------------------------------\n- Regular Season : 82 games per team
# (October – April)\n- Play-In Tournament: 7th–10th seed teams compete for\n                      the final playoff
# spots\n- Playoffs       : 16 teams (8 per conference), best-of-7\n                   series, single-elimination
# bracket style\n- NBA Finals     : Best-of-7 series between Eastern and\n                   Western Conference
# Champions (June)\n\n-------------------------------------------------------------\n\n... Output truncated at 100
# lines (observed 284).',
#             name='shell',
#             id='dc8a613c-dbfc-4d45-9110-e94c453c6cc2',
#             tool_call_id='toolu_018HC6nTLzm7Ngqkx2dH5j8B',
#             artifact={
#                 'timed_out': False,
#                 'exit_code': 0,
#                 'truncated_by_lines': True,
#                 'truncated_by_bytes': False,
#                 'total_lines': 284,
#                 'total_bytes': 12521,
#                 'redaction_matches': {}
#             }
#         ),
#         AIMessage(
#             content="The research has been successfully saved to **`nba_research.txt`**! 🏀\n\nHere's a summary of
# everything covered in the file:\n\n---\n\n### 📄 `nba_research.txt` — Contents Overview\n\n| # | Section |
# Highlights |\n|---|---------|------------|\n| 1 | **Overview** | Full name, founding date, HQ, Commissioner, 30
# teams |\n| 2 | **History** | Key milestones from 1946 to present |\n| 3 | **Structure & Conferences** | Eastern &
# Western Conferences, all 30 teams listed by division |\n| 4 | **Season Format** | Regular season, Play-In
# Tournament, Playoffs, NBA Finals |\n| 5 | **All-Time Champions** | Most titles by franchise + recent champions
# (2015–2024) |\n| 6 | **Legendary Players** | Jordan, LeBron, Kareem, Kobe, Russell, Curry & more |\n| 7 | **Key
# Awards** | MVP, Finals MVP, Rookie of the Year, DPOY, etc. |\n| 8 | **Statistical Leaders** | All-time leaders in
# points, assists, rebounds + single-game records |\n| 9 | **The NBA Draft** | Format, lottery system, notable #1
# picks |\n| 10 | **NBA Globally** | Broadcast reach, international players, global games |\n| 11 | **NBA G League**
# | Development league overview |\n| 12 | **Business & Financials** | Valuations, salary cap, media deals, revenues
# |\n| 13 | **Culture & Impact** | Fashion, music, social justice, technology |\n| 14 | **Fun Facts** | Court
# dimensions, records, trivia |\n| 15 | **Future of the NBA** | Expansion, streaming, global growth, AI & tech |",
#             additional_kwargs={},
#             response_metadata={
#                 'id': 'msg_011Ce5hvL1oBe45WKza1i2ca',
#                 'container': None,
#                 'model': 'claude-sonnet-4-6',
#                 'stop_details': None,
#                 'stop_reason': 'end_turn',
#                 'stop_sequence': None,
#                 'usage': {
#                     'cache_creation': {'ephemeral_1h_input_tokens': 0, 'ephemeral_5m_input_tokens': 0},
#                     'cache_creation_input_tokens': 0,
#                     'cache_read_input_tokens': 0,
#                     'inference_geo': 'global',
#                     'input_tokens': 4817,
#                     'output_tokens': 442,
#                     'output_tokens_details': None,
#                     'server_tool_use': None,
#                     'service_tier': 'standard'
#                 },
#                 'model_name': 'claude-sonnet-4-6',
#                 'model_provider': 'anthropic'
#             },
#             id='lc_run--01a00895-48f5-7190-b5e2-60b33f711d2a-0',
#             tool_calls=[],
#             invalid_tool_calls=[],
#             usage_metadata={
#                 'input_tokens': 4817,
#                 'output_tokens': 442,
#                 'total_tokens': 5259,
#                 'input_token_details': {
#                     'cache_read': 0,
#                     'cache_creation': 0,
#                     'ephemeral_5m_input_tokens': 0,
#                     'ephemeral_1h_input_tokens': 0
#                 }
#             }
#         )
#     ]
# }

# %%
result['messages'][-1].content
# Out:
# "The research has been successfully saved to **`nba_research.txt`**! 🏀\n\nHere's a summary of everything covered in the file:\n\n---\n\n### 📄 `nba_research.txt` — Contents Overview\n\n| # | Section | Highlights |\n|---|---------|------------|\n| 1 | **Overview** | Full name, founding date, HQ, Commissioner, 30 teams |\n| 2 | **History** | Key milestones from 1946 to present |\n| 3 | **Structure & Conferences** | Eastern & Western Conferences, all 30 teams listed by division |\n| 4 | **Season Format** | Regular season, Play-In Tournament, Playoffs, NBA Finals |\n| 5 | **All-Time Champions** | Most titles by franchise + recent champions (2015–2024) |\n| 6 | **Legendary Players** | Jordan, LeBron, Kareem, Kobe, Russell, Curry & more |\n| 7 | **Key Awards** | MVP, Finals MVP, Rookie of the Year, DPOY, etc. |\n| 8 | **Statistical Leaders** | All-time leaders in points, assists, rebounds + single-game records |\n| 9 | **The NBA Draft** | Format, lottery system, notable #1 picks |\n| 10 | **NBA Globally** | Broadcast reach, international players, global games |\n| 11 | **NBA G League** | Development league overview |\n| 12 | **Business & Financials** | Valuations, salary cap, media deals, revenues |\n| 13 | **Culture & Impact** | Fashion, music, social justice, technology |\n| 14 | **Fun Facts** | Court dimensions, records, trivia |\n| 15 | **Future of the NBA** | Expansion, streaming, global growth, AI & tech |"

# %%
result = cinebot_shell_agent.invoke({"messages": [("user", "Create a python file Hello_world.py which has a single line print('hello Mayank').")]})

# %%
print(result)
# Out:
# {
#     'messages': [
#         HumanMessage(
#             content="Create a python file Hello_world.py which has a single line print('hello Mayank').",
#             additional_kwargs={},
#             response_metadata={},
#             id='9dfd4e3b-a0d3-4006-a523-93542a6d830e'
#         ),
#         AIMessage(
#             content=[
#                 {
#                     'id': 'toolu_01BXbNfq8B4LtajNpirzJvyk',
#                     'caller': {'type': 'direct'},
#                     'input': {'command': 'echo "print(\'hello Mayank\')" > Hello_world.py'},
#                     'name': 'shell',
#                     'type': 'tool_use'
#                 }
#             ],
#             additional_kwargs={},
#             response_metadata={
#                 'id': 'msg_011Ce5j27dSrXSBHFqbHnQFz',
#                 'container': None,
#                 'model': 'claude-sonnet-4-6',
#                 'stop_details': None,
#                 'stop_reason': 'tool_use',
#                 'stop_sequence': None,
#                 'usage': {
#                     'cache_creation': {'ephemeral_1h_input_tokens': 0, 'ephemeral_5m_input_tokens': 0},
#                     'cache_creation_input_tokens': 0,
#                     'cache_read_input_tokens': 0,
#                     'inference_geo': 'global',
#                     'input_tokens': 732,
#                     'output_tokens': 67,
#                     'output_tokens_details': None,
#                     'server_tool_use': None,
#                     'service_tier': 'standard'
#                 },
#                 'model_name': 'claude-sonnet-4-6',
#                 'model_provider': 'anthropic'
#             },
#             id='lc_run--01a008a2-7cea-7462-9534-89540a7617f0-0',
#             tool_calls=[
#                 {
#                     'name': 'shell',
#                     'args': {'command': 'echo "print(\'hello Mayank\')" > Hello_world.py'},
#                     'id': 'toolu_01BXbNfq8B4LtajNpirzJvyk',
#                     'type': 'tool_call'
#                 }
#             ],
#             invalid_tool_calls=[],
#             usage_metadata={
#                 'input_tokens': 732,
#                 'output_tokens': 67,
#                 'total_tokens': 799,
#                 'input_token_details': {
#                     'cache_read': 0,
#                     'cache_creation': 0,
#                     'ephemeral_5m_input_tokens': 0,
#                     'ephemeral_1h_input_tokens': 0
#                 }
#             }
#         ),
#         ToolMessage(
#             content='<no output>',
#             name='shell',
#             id='062847c4-666e-4a90-b0b4-dfa250299c7c',
#             tool_call_id='toolu_01BXbNfq8B4LtajNpirzJvyk',
#             artifact={
#                 'timed_out': False,
#                 'exit_code': 0,
#                 'truncated_by_lines': False,
#                 'truncated_by_bytes': False,
#                 'total_lines': 0,
#                 'total_bytes': 0,
#                 'redaction_matches': {}
#             }
#         ),
#         AIMessage(
#             content=[
#                 {'text': 'Let me verify the file was created correctly:', 'type': 'text'},
#                 {
#                     'id': 'toolu_0116Y4vvmimPqxwiMqkgftJg',
#                     'caller': {'type': 'direct'},
#                     'input': {'command': 'cat Hello_world.py'},
#                     'name': 'shell',
#                     'type': 'tool_use'
#                 }
#             ],
#             additional_kwargs={},
#             response_metadata={
#                 'id': 'msg_011Ce5j2EmK3DFHKBCRC8Vyx',
#                 'container': None,
#                 'model': 'claude-sonnet-4-6',
#                 'stop_details': None,
#                 'stop_reason': 'tool_use',
#                 'stop_sequence': None,
#                 'usage': {
#                     'cache_creation': {'ephemeral_1h_input_tokens': 0, 'ephemeral_5m_input_tokens': 0},
#                     'cache_creation_input_tokens': 0,
#                     'cache_read_input_tokens': 0,
#                     'inference_geo': 'global',
#                     'input_tokens': 813,
#                     'output_tokens': 66,
#                     'output_tokens_details': None,
#                     'server_tool_use': None,
#                     'service_tier': 'standard'
#                 },
#                 'model_name': 'claude-sonnet-4-6',
#                 'model_provider': 'anthropic'
#             },
#             id='lc_run--01a008a2-8351-7542-83e6-af99ca2142ea-0',
#             tool_calls=[
#                 {
#                     'name': 'shell',
#                     'args': {'command': 'cat Hello_world.py'},
#                     'id': 'toolu_0116Y4vvmimPqxwiMqkgftJg',
#                     'type': 'tool_call'
#                 }
#             ],
#             invalid_tool_calls=[],
#             usage_metadata={
#                 'input_tokens': 813,
#                 'output_tokens': 66,
#                 'total_tokens': 879,
#                 'input_token_details': {
#                     'cache_read': 0,
#                     'cache_creation': 0,
#                     'ephemeral_5m_input_tokens': 0,
#                     'ephemeral_1h_input_tokens': 0
#                 }
#             }
#         ),
#         ToolMessage(
#             content="print('hello Mayank')\n",
#             name='shell',
#             id='9fcccf68-a515-41af-bfcd-a61bba16a5cb',
#             tool_call_id='toolu_0116Y4vvmimPqxwiMqkgftJg',
#             artifact={
#                 'timed_out': False,
#                 'exit_code': 0,
#                 'truncated_by_lines': False,
#                 'truncated_by_bytes': False,
#                 'total_lines': 1,
#                 'total_bytes': 22,
#                 'redaction_matches': {}
#             }
#         ),
#         AIMessage(
#             content="The file `Hello_world.py` has been created successfully! Here's a summary of what was
# done:\n\n- **File Name:** `Hello_world.py`\n- **Content:** `print('hello Mayank')`\n\nYou can run it using the
# command `python Hello_world.py`, and it will output:\n```\nhello Mayank\n```",
#             additional_kwargs={},
#             response_metadata={
#                 'id': 'msg_011Ce5j2PaPcJtDe9DdxjYPS',
#                 'container': None,
#                 'model': 'claude-sonnet-4-6',
#                 'stop_details': None,
#                 'stop_reason': 'end_turn',
#                 'stop_sequence': None,
#                 'usage': {
#                     'cache_creation': {'ephemeral_1h_input_tokens': 0, 'ephemeral_5m_input_tokens': 0},
#                     'cache_creation_input_tokens': 0,
#                     'cache_read_input_tokens': 0,
#                     'inference_geo': 'global',
#                     'input_tokens': 899,
#                     'output_tokens': 83,
#                     'output_tokens_details': None,
#                     'server_tool_use': None,
#                     'service_tier': 'standard'
#                 },
#                 'model_name': 'claude-sonnet-4-6',
#                 'model_provider': 'anthropic'
#             },
#             id='lc_run--01a008a2-8be6-7d63-b1fd-7acef1c5be66-0',
#             tool_calls=[],
#             invalid_tool_calls=[],
#             usage_metadata={
#                 'input_tokens': 899,
#                 'output_tokens': 83,
#                 'total_tokens': 982,
#                 'input_token_details': {
#                     'cache_read': 0,
#                     'cache_creation': 0,
#                     'ephemeral_5m_input_tokens': 0,
#                     'ephemeral_1h_input_tokens': 0
#                 }
#             }
#         )
#     ]
# }

# %%
result = cinebot_shell_agent.invoke({"messages": [("user", "Create a python script which creates 2 folders with langchain_1 and langchain_2, just create the script.")]})

# %%
result = cinebot_shell_agent.invoke({"messages": [("user", "run the create_folders.py.")]})

# %%
result = cinebot_shell_agent.invoke({"messages": [("user", "Delete the create_folders.py.")]})

# %%
result = cinebot_shell_agent.invoke({"messages": [("user", "Create a file which runs a small calculator app. simple one which can run")]})
