# %%
import urllib.error
import urllib.request
import pprint
from langchain.tools import tool

from langchain.chat_models import init_chat_model

import langchain_groq
import os

from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
model_groq_lamma70b = init_chat_model("llama-3.3-70b-versatile",
                        api_key=os.environ["GROQ_API_KEY"],
                        model_provider="groq",
                        # base_url="https://api.groq.com/openai/v1",
                        max_tokens=10000, temperature=0.0)

# model = init_chat_model("openai/gpt-4o-mini",
#                         api_key=os.environ["OPENROUTER_API_KEY"],
#                         model_provider="openrouter",
#                         base_url="https://openrouter.ai/api/v1",
#                         max_tokens=1000, temperature=0.0)

# model = init_chat_model("nvidia/nemotron-3-ultra-550b-a55b:free",
#                         api_key=os.environ["OPENROUTER_API_KEY"],
#                         model_provider="openrouter",
#                         base_url="https://openrouter.ai/api/v1",
#                         max_tokens=1000, temperature=0.0)


# model = init_chat_model("openrouter/free",
#                         api_key=os.environ["OPENROUTER_API_KEY"],
#                         model_provider="openrouter",
#                         base_url="https://openrouter.ai/api/v1",
#                         max_tokens=1000, temperature=0.0)


model_or = init_chat_model("openrouter/free",
                        api_key=os.environ["OPENROUTER_API_KEY"],
                        model_provider="openrouter",
                        base_url="https://openrouter.ai/api/v1",
                        max_tokens=1000, temperature=0.0)

model_or_paid_gpt56_luna_pro = init_chat_model("openai/gpt-5.6-luna-pro",
                        api_key=os.environ["OPENROUTER_API_KEY"],
                        model_provider="openrouter",
                        base_url="https://openrouter.ai/api/v1",
                        max_tokens=10000, temperature=0.0)

# %%
from langchain.agents import create_agent
from langchain.tools import tool
from langchain_openai import ChatOpenAI


@tool(return_direct=True)
def fetch_order_status(order_id: str) -> str:
    """Fetch the current status of a customer order."""
    # In production, query your order management system here
    return f"Order {order_id} is shipped and will arrive in 2 days."



agent = create_agent(
    model=model_or_paid_gpt56_luna_pro,
    tools=[fetch_order_status],
)

# %%
result = agent.invoke({
    "messages": [{"role": "user", "content": "What is the status of order #12345?"}]
})
# The agent returns the tool output directly without another LLM call:
# "Order 12345 is shipped and will arrive in 2 days."

# %% [markdown]
# ## Return directly from a tool
# Set return direct on a tool to ```short-circuit``` the agent loop: the agent returns the tool’s output to the caller immediately, without sending it back through the model for further processing.
# ##### The last message will be the tool message when retun_direct=True in the tool decorator

# %%
from rich import print as rprint
rprint(result)
# Out:
# {
#     'messages': [
#         HumanMessage(
#             content='What is the status of order #12345?',
#             additional_kwargs={},
#             response_metadata={},
#             id='284c6f00-8ce3-47a2-aa43-a54ae1fb0331'
#         ),
#         AIMessage(
#             content='',
#             additional_kwargs={},
#             response_metadata={
#                 'model_name': 'openai/gpt-5.6-luna-pro',
#                 'id': 'gen-1786802507-p6hv1QuNn91TOJaSD132',
#                 'created': 1786802507,
#                 'object': 'chat.completion',
#                 'finish_reason': 'tool_calls',
#                 'logprobs': None,
#                 'model_provider': 'openrouter',
#                 'cost': 0.0002392,
#                 'cost_details': {
#                     'upstream_inference_completions_cost': 7.08e-05,
#                     'upstream_inference_prompt_cost': 0.0001684,
#                     'upstream_inference_cost': 0.0002392
#                 }
#             },
#             id='lc_run--01a005ba-8983-7532-9ce5-ccd7caa7d80a-0',
#             tool_calls=[
#                 {
#                     'name': 'fetch_order_status',
#                     'args': {'order_id': '12345'},
#                     'id': 'call_eoCoaMfb4GTYZm1VoTfcNsb8',
#                     'type': 'tool_call'
#                 }
#             ],
#             invalid_tool_calls=[],
#             usage_metadata={
#                 'input_tokens': 1684,
#                 'output_tokens': 118,
#                 'total_tokens': 1802,
#                 'input_token_details': {'cache_read': 0, 'cache_creation': 0},
#                 'output_token_details': {'reasoning': 36}
#             }
#         ),
#         ToolMessage(
#             content='Order 12345 is shipped and will arrive in 2 days.',
#             name='fetch_order_status',
#             id='cbdbc441-7f7e-4643-91b8-d81e7b012704',
#             tool_call_id='call_eoCoaMfb4GTYZm1VoTfcNsb8'
#         )
#     ]
# }

# %% [markdown]
# ##### The last message will be the ai message when retun_direct=False in the tool decorator

# %%
@tool()
def fetch_order_status1(order_id: str) -> str:
    """Fetch the current status of a customer order."""
    # In production, query your order management system here
    return f"Order {order_id} is shipped and will arrive in 2 days."



agent1 = create_agent(
    model=model_or_paid_gpt56_luna_pro,
    tools=[fetch_order_status1],
)

# %% [markdown]
# ##### The last message will be the tool message when retun_direct=True in the tool decorator

# %%
result1 = agent1.invoke({
    "messages": [{"role": "user", "content": "What is the status of order #12345?"}]
})

rprint(result1)
# Out:
# {
#     'messages': [
#         HumanMessage(
#             content='What is the status of order #12345?',
#             additional_kwargs={},
#             response_metadata={},
#             id='9691a86e-1bcd-4a11-b2ba-9d8f28cd8c66'
#         ),
#         AIMessage(
#             content='',
#             additional_kwargs={},
#             response_metadata={
#                 'model_name': 'openai/gpt-5.6-luna-pro',
#                 'id': 'gen-1786802665-vICiz8bIFHmd9Z0Xvvmi',
#                 'created': 1786802665,
#                 'object': 'chat.completion',
#                 'finish_reason': 'tool_calls',
#                 'logprobs': None,
#                 'model_provider': 'openrouter',
#                 'cost': 0.0002342,
#                 'cost_details': {
#                     'upstream_inference_completions_cost': 6.6e-05,
#                     'upstream_inference_prompt_cost': 0.0001682,
#                     'upstream_inference_cost': 0.0002342
#                 }
#             },
#             id='lc_run--01a005bc-f1f7-7283-b536-20569360297f-0',
#             tool_calls=[
#                 {
#                     'name': 'fetch_order_status1',
#                     'args': {'order_id': '12345'},
#                     'id': 'call_JCbscZZuO834c9x04nD6NJCz',
#                     'type': 'tool_call'
#                 }
#             ],
#             invalid_tool_calls=[],
#             usage_metadata={
#                 'input_tokens': 1682,
#                 'output_tokens': 110,
#                 'total_tokens': 1792,
#                 'input_token_details': {'cache_read': 0, 'cache_creation': 0},
#                 'output_token_details': {'reasoning': 27}
#             }
#         ),
#         ToolMessage(
#             content='Order 12345 is shipped and will arrive in 2 days.',
#             name='fetch_order_status1',
#             id='069cd4bf-6fcc-4dd7-8723-87d1222ded10',
#             tool_call_id='call_JCbscZZuO834c9x04nD6NJCz'
#         ),
#         AIMessage(
#             content='Order **#12345** has been **shipped** and is expected to arrive in **2 days**.',
#             additional_kwargs={},
#             response_metadata={
#                 'model_name': 'openai/gpt-5.6-luna-pro',
#                 'id': 'gen-1786802667-akFuA1xwHaZQRY0hsRZ6',
#                 'created': 1786802667,
#                 'object': 'chat.completion',
#                 'finish_reason': 'stop',
#                 'logprobs': None,
#                 'model_provider': 'openrouter',
#                 'cost': 0.0002747,
#                 'cost_details': {
#                     'upstream_inference_completions_cost': 8.7e-05,
#                     'upstream_inference_prompt_cost': 0.0001877,
#                     'upstream_inference_cost': 0.0002747
#                 }
#             },
#             id='lc_run--01a005bc-fc77-77b2-8331-2d2e30753cdf-0',
#             tool_calls=[],
#             invalid_tool_calls=[],
#             usage_metadata={
#                 'input_tokens': 1877,
#                 'output_tokens': 145,
#                 'total_tokens': 2022,
#                 'input_token_details': {'cache_read': 0, 'cache_creation': 0},
#                 'output_token_details': {'reasoning': 47}
#             }
#         )
#     ]
# }
