# %%
import pprint
from langchain.tools import tool
from langchain.chat_models import init_chat_model
from langchain_groq import ChatGroq
from langchain_openai import ChatOpenAI
from langchain.agents import create_agent
from typing_extensions import TypedDict
from langchain.agents.structured_output import ToolStrategy, ProviderStrategy
import os

from dotenv import load_dotenv

load_dotenv("C:\\Users\\socgen\\ML\\agentic_ai_and_ops\\langchain_day5\\.env")
# Out:
# True

# %%
model_gr_lamma = init_chat_model("llama-3.3-70b-versatile",
                        api_key=os.environ["GROQ_API_KEY"],
                        model_provider="groq",
                        # base_url="https://api.groq.com/openai/v1",
                        max_tokens=1000, temperature=0.0)

model_or_paid_gpt_luna_pro = init_chat_model("openai/gpt-5.6-luna-pro",
                        api_key=os.environ["OPENROUTER_API_KEY"],
                        model_provider="openrouter",
                        base_url="https://openrouter.ai/api/v1",
                        max_tokens=100, temperature=0.0)

model_or_free_nvidia = init_chat_model("nvidia/nemotron-3-ultra-550b-a55b:free",
                        api_key=os.environ["OPENROUTER_API_KEY"],
                        model_provider="openrouter",
                        base_url="https://openrouter.ai/api/v1",
                        max_tokens=1000, temperature=0.0)


model_or_free = init_chat_model("openrouter/free",
                        api_key=os.environ["OPENROUTER_API_KEY"],
                        model_provider="openrouter",
                        base_url="https://openrouter.ai/api/v1",
                        max_tokens=1000, temperature=0.0)


model_ollama = init_chat_model("ollama:gemma4:latest",
                                max_tokens=200, 
                                temperature=0.0)

# %%
from typing import Literal

class ProductReview(TypedDict):
    product_name: str
    review_text: str
    rating: Literal[1, 2, 3, 4, 5]
    shipping_sentiment: Literal["positive", "negative", "neutral"]
    pricing_sentiment: Literal["positive", "negative", "neutral"]
    quality_sentiment: Literal["positive", "negative", "neutral"]

# %%
agent = create_agent(
    model=model_gr_lamma,
    tools=[],
    # response_format=ProductReview,
    response_format=ToolStrategy(
        ProductReview
    ))

# %%
result=agent.invoke({
    "messages": [{"role": "user", "content": "Analyze this review: 'Great TShirt: 5 out of 5 stars. slow shipping, and expensive'"}]
})

# %%
result
# Out:
# {'messages': [HumanMessage(content="Analyze this review: 'Great TShirt: 5 out of 5 stars. slow shipping, and expensive'", additional_kwargs={}, response_metadata={}, id='fe0d9b8e-3c9a-42cd-9095-9311d1d5e8cf'),
#   AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'rjpnmn6w1', 'function': {'arguments': '{"pricing_sentiment":"negative","product_name":"TShirt","quality_sentiment":"positive","rating":5,"review_text":"Great TShirt: 5 out of 5 stars. slow shipping, and expensive","shipping_sentiment":"negative"}', 'name': 'ProductReview'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 69, 'prompt_tokens': 331, 'total_tokens': 400, 'completion_time': 0.150170872, 'completion_tokens_details': None, 'prompt_time': 0.016545924, 'prompt_tokens_details': None, 'queue_time': 0.049994059, 'total_time': 0.166716796}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_dae98b5ecb', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019fca21-3a12-7f43-9480-15be42b4219f-0', tool_calls=[{'name': 'ProductReview', 'args': {'pricing_sentiment': 'negative', 'product_name': 'TShirt', 'quality_sentiment': 'positive', 'rating': 5, 'review_text': 'Great TShirt: 5 out of 5 stars. slow shipping, and expensive', 'shipping_sentiment': 'negative'}, 'id': 'rjpnmn6w1', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 331, 'output_tokens': 69, 'total_tokens': 400}),
#   ToolMessage(content="Returning structured response: {'product_name': 'TShirt', 'review_text': 'Great TShirt: 5 out of 5 stars. slow shipping, and expensive', 'rating': 5, 'shipping_sentiment': 'negative', 'pricing_sentiment': 'negative', 'quality_sentiment': 'positive'}", name='ProductReview', id='d4bb7f52-ed06-4fc2-8b1f-4451e46a78f1', tool_call_id='rjpnmn6w1')],
#  'structured_response': {'product_name': 'TShirt',
#   'review_text': 'Great TShirt: 5 out of 5 stars. slow shipping, and expensive',
#   'rating': 5,
#   'shipping_sentiment': 'negative',
#   'pricing_sentiment': 'negative',
#   'quality_sentiment': 'positive'}}

# %%
result
# Out:
# {'messages': [HumanMessage(content="Analyze this review: 'Great TShirt: 5 out of 5 stars. slow shipping, and expensive'", additional_kwargs={}, response_metadata={}, id='1a77e3f7-0344-4ba7-b1b7-c2cccd380e87'),
#   AIMessage(content='', additional_kwargs={'tool_calls': [{'id': '4nwstaedj', 'function': {'arguments': '{"pricing_sentiment":"negative","product_name":"TShirt","quality_sentiment":"positive","rating":5,"review_text":"Great TShirt: 5 out of 5 stars. slow shipping, and expensive","shipping_sentiment":"negative"}', 'name': 'ProductReview'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 69, 'prompt_tokens': 331, 'total_tokens': 400, 'completion_time': 0.144187918, 'completion_tokens_details': None, 'prompt_time': 0.017241513, 'prompt_tokens_details': None, 'queue_time': 0.161860736, 'total_time': 0.161429431}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_45180df409', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019fca1e-ecad-7862-9972-aeb2c15738cb-0', tool_calls=[{'name': 'ProductReview', 'args': {'pricing_sentiment': 'negative', 'product_name': 'TShirt', 'quality_sentiment': 'positive', 'rating': 5, 'review_text': 'Great TShirt: 5 out of 5 stars. slow shipping, and expensive', 'shipping_sentiment': 'negative'}, 'id': '4nwstaedj', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 331, 'output_tokens': 69, 'total_tokens': 400}),
#   ToolMessage(content="Returning structured response: {'product_name': 'TShirt', 'review_text': 'Great TShirt: 5 out of 5 stars. slow shipping, and expensive', 'rating': 5, 'shipping_sentiment': 'negative', 'pricing_sentiment': 'negative', 'quality_sentiment': 'positive'}", name='ProductReview', id='1c028b47-4f18-4f54-a960-18516687690d', tool_call_id='4nwstaedj')],
#  'structured_response': {'product_name': 'TShirt',
#   'review_text': 'Great TShirt: 5 out of 5 stars. slow shipping, and expensive',
#   'rating': 5,
#   'shipping_sentiment': 'negative',
#   'pricing_sentiment': 'negative',
#   'quality_sentiment': 'positive'}}

# %%
result["structured_response"]
# Out:
# {'product_name': 'TShirt',
#  'review_text': 'Great TShirt: 5 out of 5 stars. slow shipping, and expensive',
#  'rating': 5,
#  'shipping_sentiment': 'negative',
#  'pricing_sentiment': 'negative',
#  'quality_sentiment': 'positive'}
